# %%
# Import the random module.
import random

# Import the NumPy module.
import numpy as np

# Import the Pandas module.
import pandas as pd

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Import the requests library.
import requests

# Import the API key.
from config_copy import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})
        # If an error is experienced, skip the city.
    except (KeyError):
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | vardo
# Processing Record 2 of Set 1 | ribeira grande
# Processing Record 3 of Set 1 | port elizabeth
# Processing Record 4 of Set 1 | maceio
# Processing Record 5 of Set 1 | ylojarvi
# Processing Record 6 of Set 1 | hami
# Processing Record 7 of Set 1 | novorzhev
# Processing Record 8 of Set 1 | saint-philippe
# Processing Record 9 of Set 1 | alyangula
# Processing Record 10 of Set 1 | kutum
# Processing Record 11 of Set 1 | sitka
# Processing Record 12 of Set 1 | barrow
# Processing Record 13 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 14 of Set 1 | east london
# Processing Record 15 of Set 1 | ishigaki
# Processing Record 16 of Set 1 | ngawi
# Processing Record 17 of Set 1 | berlevag
# Processing Record 18 of Set 1 | ercis
# Processing Record 19 of Set 1 | aklavik
# Processing Record 20 of Set 1 | vao
# Processing Record 21 of Set 1 | hamilton
# Processing Record 22 of Set 1 | coihaique
# Processing Record 23 of Set 1 | yellowknife
# Processing Record 24 of Set 1 | mbacke
# City not found. Skipping...
# Processing Record 25 of Set 1 | busselton
# Processing Record 26 of Set 1 | ushuaia
# Processing Record 27 of Set 1 | sechura
# Processing Record 28 of Set 1 | arraial do cabo
# Processing Record 29 of Set 1 | tuktoyaktuk
# Processing Record 30 of Set 1 | qaanaaq
# Processing Record 31 of Set 1 | port lincoln
# Processing Record 32 of Set 1 | saurimo
# Processing Record 33 of Set 1 | san rafael
# Processing Record 34 of Set 1 | port hawkesbury
# Processing Record 35 of Set 1 | cabo san lucas
# Processing Record 36 of Set 1 | esperance
# Processing Record 37 of Set 1 | avarua
# Processing Record 38 of Set 1 | sakakah
# Processing Record 39 of Set 1 | bennington
# Processing Record 40 of Set 1 | poykovskiy
# Processing Record 41 of Set 1 | saint-pierre
# Processing Record 42 of Set 1 | hermanus
# Processing Record 43 of Set 1 | waterloo
# Processing Record 44 of Set 1 | sept-iles
# Processing Record 45 of Set 1 | rikitea
# Processing Record 46 of Set 1 | labuhan
# Processing Record 47 of Set 1 | broome
# Processing Record 48 of Set 1 | mataura
# Processing Record 49 of Set 1 | kutiyana
# Processing Record 50 of Set 1 | louisbourg
# City not found. Skipping...
# Processing Record 1 of Set 2 | georgetown
# Processing Record 2 of Set 2 | udachnyy
# Processing Record 3 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 4 of Set 2 | norman wells
# Processing Record 5 of Set 2 | hithadhoo
# Processing Record 6 of Set 2 | sorland
# Processing Record 7 of Set 2 | torit
# Processing Record 8 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 9 of Set 2 | goderich
# Processing Record 10 of Set 2 | kachiry
# Processing Record 11 of Set 2 | vaini
# Processing Record 12 of Set 2 | albany
# Processing Record 13 of Set 2 | dayong
# Processing Record 14 of Set 2 | cape town
# Processing Record 15 of Set 2 | male
# Processing Record 16 of Set 2 | guerrero negro
# Processing Record 17 of Set 2 | beringovskiy
# Processing Record 18 of Set 2 | torbay
# Processing Record 19 of Set 2 | north bend
# Processing Record 20 of Set 2 | bredasdorp
# Processing Record 21 of Set 2 | puerto leguizamo
# Processing Record 22 of Set 2 | henderson
# Processing Record 23 of Set 2 | hervey bay
# Processing Record 24 of Set 2 | umm kaddadah
# Processing Record 25 of Set 2 | umm lajj
# Processing Record 26 of Set 2 | airai
# Processing Record 27 of Set 2 | punta arenas
# Processing Record 28 of Set 2 | nouakchott
# Processing Record 29 of Set 2 | ginir
# Processing Record 30 of Set 2 | ilulissat
# Processing Record 31 of Set 2 | jamestown
# Processing Record 32 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 33 of Set 2 | tuatapere
# Processing Record 34 of Set 2 | shingu
# Processing Record 35 of Set 2 | pochutla
# Processing Record 36 of Set 2 | castro
# Processing Record 37 of Set 2 | port alfred
# Processing Record 38 of Set 2 | upper arlington
# Processing Record 39 of Set 2 | makakilo city
# Processing Record 40 of Set 2 | druzhba
# Processing Record 41 of Set 2 | bardiyah
# Processing Record 42 of Set 2 | nikolskoye
# Processing Record 43 of Set 2 | dikson
# Processing Record 44 of Set 2 | vicente guerrero
# Processing Record 45 of Set 2 | hobart
# Processing Record 46 of Set 2 | solnechnyy
# Processing Record 47 of Set 2 | lompoc
# Processing Record 48 of Set 2 | bereda
# Processing Record 49 of Set 2 | husavik
# Processing Record 50 of Set 2 | new norfolk
# Processing Record 1 of Set 3 | baruun-urt
# Processing Record 2 of Set 3 | pisco
# Processing Record 3 of Set 3 | navashino
# Processing Record 4 of Set 3 | thaba-tseka
# Processing Record 5 of Set 3 | atuona
# Processing Record 6 of Set 3 | padang
# Processing Record 7 of Set 3 | iqaluit
# Processing Record 8 of Set 3 | buchanan
# Processing Record 9 of Set 3 | bara
# Processing Record 10 of Set 3 | klaksvik
# Processing Record 11 of Set 3 | chokurdakh
# Processing Record 12 of Set 3 | tezu
# Processing Record 13 of Set 3 | dunedin
# Processing Record 14 of Set 3 | thompson
# Processing Record 15 of Set 3 | kharp
# Processing Record 16 of Set 3 | bethel
# Processing Record 17 of Set 3 | havelock
# Processing Record 18 of Set 3 | jujuy
# City not found. Skipping...
# Processing Record 19 of Set 3 | carballo
# Processing Record 20 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 21 of Set 3 | khatanga
# Processing Record 22 of Set 3 | riom
# Processing Record 23 of Set 3 | poso
# Processing Record 24 of Set 3 | richards bay
# Processing Record 25 of Set 3 | hilo
# Processing Record 26 of Set 3 | bluff
# Processing Record 27 of Set 3 | bogorodskoye
# Processing Record 28 of Set 3 | hualmay
# Processing Record 29 of Set 3 | evensk
# Processing Record 30 of Set 3 | siruguppa
# Processing Record 31 of Set 3 | bima
# Processing Record 32 of Set 3 | kavieng
# Processing Record 33 of Set 3 | halalo
# City not found. Skipping...
# Processing Record 34 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 35 of Set 3 | athens
# Processing Record 36 of Set 3 | margate
# Processing Record 37 of Set 3 | butaritari
# Processing Record 38 of Set 3 | kruisfontein
# Processing Record 39 of Set 3 | ponta do sol
# Processing Record 40 of Set 3 | bambous virieux
# Processing Record 41 of Set 3 | fortuna
# Processing Record 42 of Set 3 | chandler
# Processing Record 43 of Set 3 | college
# Processing Record 44 of Set 3 | saldanha
# Processing Record 45 of Set 3 | chuy
# Processing Record 46 of Set 3 | torrington
# Processing Record 47 of Set 3 | cusuna
# Processing Record 48 of Set 3 | bathsheba
# Processing Record 49 of Set 3 | cidreira
# Processing Record 50 of Set 3 | mersing
# Processing Record 1 of Set 4 | tondon
# Processing Record 2 of Set 4 | goianesia
# Processing Record 3 of Set 4 | kargopol
# Processing Record 4 of Set 4 | amazar
# Processing Record 5 of Set 4 | mvuma
# Processing Record 6 of Set 4 | kuytun
# Processing Record 7 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 8 of Set 4 | kirkwall
# Processing Record 9 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 10 of Set 4 | ximei
# Processing Record 11 of Set 4 | krasnoselkup
# Processing Record 12 of Set 4 | pangody
# Processing Record 13 of Set 4 | quatre cocos
# Processing Record 14 of Set 4 | bonavista
# Processing Record 15 of Set 4 | thano bula khan
# City not found. Skipping...
# Processing Record 16 of Set 4 | sondrio
# Processing Record 17 of Set 4 | pirojpur
# Processing Record 18 of Set 4 | kapaa
# Processing Record 19 of Set 4 | prabumulih
# Processing Record 20 of Set 4 | vestmannaeyjar
# Processing Record 21 of Set 4 | luderitz
# Processing Record 22 of Set 4 | narsaq
# Processing Record 23 of Set 4 | omboue
# Processing Record 24 of Set 4 | mar del plata
# Processing Record 25 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 26 of Set 4 | hambantota
# Processing Record 27 of Set 4 | bonfim
# Processing Record 28 of Set 4 | sabha
# Processing Record 29 of Set 4 | praia da vitoria
# Processing Record 30 of Set 4 | hasaki
# Processing Record 31 of Set 4 | sompeta
# Processing Record 32 of Set 4 | talnakh
# Processing Record 33 of Set 4 | breytovo
# Processing Record 34 of Set 4 | mago
# Processing Record 35 of Set 4 | valparaiso
# Processing Record 36 of Set 4 | ostrovnoy
# Processing Record 37 of Set 4 | puri
# Processing Record 38 of Set 4 | salta
# Processing Record 39 of Set 4 | mundra
# Processing Record 40 of Set 4 | manicore
# Processing Record 41 of Set 4 | rio grande
# Processing Record 42 of Set 4 | bradford
# Processing Record 43 of Set 4 | puerto ayora
# Processing Record 44 of Set 4 | port-cartier
# Processing Record 45 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 4 | fernie
# Processing Record 47 of Set 4 | teya
# Processing Record 48 of Set 4 | waipawa
# Processing Record 49 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 50 of Set 4 | zambezi
# Processing Record 1 of Set 5 | okha
# Processing Record 2 of Set 5 | henties bay
# Processing Record 3 of Set 5 | bida
# Processing Record 4 of Set 5 | kattivakkam
# Processing Record 5 of Set 5 | caravelas
# Processing Record 6 of Set 5 | mahebourg
# Processing Record 7 of Set 5 | nuuk
# Processing Record 8 of Set 5 | jimma
# Processing Record 9 of Set 5 | madang
# Processing Record 10 of Set 5 | luganville
# Processing Record 11 of Set 5 | colquechaca
# Processing Record 12 of Set 5 | naryan-mar
# Processing Record 13 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 14 of Set 5 | kodiak
# Processing Record 15 of Set 5 | nanyamba
# Processing Record 16 of Set 5 | shawville
# Processing Record 17 of Set 5 | atambua
# Processing Record 18 of Set 5 | juneau
# Processing Record 19 of Set 5 | viedma
# Processing Record 20 of Set 5 | axim
# Processing Record 21 of Set 5 | taoudenni
# Processing Record 22 of Set 5 | nanortalik
# Processing Record 23 of Set 5 | zarubino
# Processing Record 24 of Set 5 | gunjur
# Processing Record 25 of Set 5 | kaniama
# Processing Record 26 of Set 5 | kununurra
# Processing Record 27 of Set 5 | kemijarvi
# Processing Record 28 of Set 5 | clyde river
# Processing Record 29 of Set 5 | provideniya
# Processing Record 30 of Set 5 | victoria
# Processing Record 31 of Set 5 | muzhi
# Processing Record 32 of Set 5 | sinkat
# City not found. Skipping...
# Processing Record 33 of Set 5 | saint george
# Processing Record 34 of Set 5 | kaitangata
# Processing Record 35 of Set 5 | gouyave
# Processing Record 36 of Set 5 | waynesboro
# Processing Record 37 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 38 of Set 5 | sairang
# Processing Record 39 of Set 5 | barbacoas
# Processing Record 40 of Set 5 | pacific grove
# Processing Record 41 of Set 5 | fare
# Processing Record 42 of Set 5 | emiliano zapata
# Processing Record 43 of Set 5 | jalor
# Processing Record 44 of Set 5 | kamenka
# Processing Record 45 of Set 5 | miles city
# Processing Record 46 of Set 5 | vila franca do campo
# Processing Record 47 of Set 5 | mulchen
# Processing Record 48 of Set 5 | isperih
# Processing Record 49 of Set 5 | seoul
# Processing Record 50 of Set 5 | cockburn town
# Processing Record 1 of Set 6 | touros
# Processing Record 2 of Set 6 | sofiysk
# City not found. Skipping...
# Processing Record 3 of Set 6 | potiskum
# Processing Record 4 of Set 6 | kysyl-syr
# Processing Record 5 of Set 6 | gayeri
# Processing Record 6 of Set 6 | yialos
# City not found. Skipping...
# Processing Record 7 of Set 6 | constitucion
# Processing Record 8 of Set 6 | tiksi
# Processing Record 9 of Set 6 | thunder bay
# Processing Record 10 of Set 6 | upernavik
# Processing Record 11 of Set 6 | shagamu
# Processing Record 12 of Set 6 | san patricio
# Processing Record 13 of Set 6 | cabedelo
# Processing Record 14 of Set 6 | mocambique
# City not found. Skipping...
# Processing Record 15 of Set 6 | faanui
# Processing Record 16 of Set 6 | saskylakh
# Processing Record 17 of Set 6 | agadir
# Processing Record 18 of Set 6 | souillac
# Processing Record 19 of Set 6 | lavrentiya
# Processing Record 20 of Set 6 | sao filipe
# Processing Record 21 of Set 6 | hammerfest
# Processing Record 22 of Set 6 | vanimo
# Processing Record 23 of Set 6 | quelimane
# Processing Record 24 of Set 6 | ekibastuz
# Processing Record 25 of Set 6 | slave lake
# Processing Record 26 of Set 6 | broken hill
# Processing Record 27 of Set 6 | grindavik
# Processing Record 28 of Set 6 | kahului
# Processing Record 29 of Set 6 | krechevitsy
# Processing Record 30 of Set 6 | tshela
# Processing Record 31 of Set 6 | zhigansk
# Processing Record 32 of Set 6 | san quintin
# Processing Record 33 of Set 6 | shelburne
# Processing Record 34 of Set 6 | cherskiy
# Processing Record 35 of Set 6 | lagoa
# Processing Record 36 of Set 6 | walker
# Processing Record 37 of Set 6 | sesheke
# Processing Record 38 of Set 6 | vavoua
# Processing Record 39 of Set 6 | lubao
# Processing Record 40 of Set 6 | mahibadhoo
# Processing Record 41 of Set 6 | namibe
# Processing Record 42 of Set 6 | nome
# Processing Record 43 of Set 6 | rocha
# Processing Record 44 of Set 6 | lakes entrance
# Processing Record 45 of Set 6 | naruto
# Processing Record 46 of Set 6 | uruzgan
# Processing Record 47 of Set 6 | tasiilaq
# Processing Record 48 of Set 6 | sete
# Processing Record 49 of Set 6 | naze
# Processing Record 50 of Set 6 | ajaccio
# Processing Record 1 of Set 7 | mildura
# Processing Record 2 of Set 7 | high level
# Processing Record 3 of Set 7 | codrington
# Processing Record 4 of Set 7 | yerbogachen
# Processing Record 5 of Set 7 | tashtyp
# Processing Record 6 of Set 7 | kandrian
# Processing Record 7 of Set 7 | eyl
# Processing Record 8 of Set 7 | vila velha
# Processing Record 9 of Set 7 | coihueco
# Processing Record 10 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 11 of Set 7 | igrim
# Processing Record 12 of Set 7 | brewster
# Processing Record 13 of Set 7 | tulun
# Processing Record 14 of Set 7 | katsuura
# Processing Record 15 of Set 7 | fernley
# Processing Record 16 of Set 7 | hay river
# Processing Record 17 of Set 7 | matagami
# Processing Record 18 of Set 7 | tateyama
# Processing Record 19 of Set 7 | severo-kurilsk
# Processing Record 20 of Set 7 | imeni poliny osipenko
# Processing Record 21 of Set 7 | sao jose da coroa grande
# Processing Record 22 of Set 7 | sanchazi
# Processing Record 23 of Set 7 | simao
# Processing Record 24 of Set 7 | homer
# Processing Record 25 of Set 7 | erzin
# Processing Record 26 of Set 7 | paamiut
# Processing Record 27 of Set 7 | itoman
# Processing Record 28 of Set 7 | galle
# Processing Record 29 of Set 7 | kidal
# Processing Record 30 of Set 7 | alofi
# Processing Record 31 of Set 7 | ponta delgada
# Processing Record 32 of Set 7 | saint augustine
# Processing Record 33 of Set 7 | maragogi
# Processing Record 34 of Set 7 | asyut
# Processing Record 35 of Set 7 | somerset east
# Processing Record 36 of Set 7 | aripuana
# Processing Record 37 of Set 7 | farafangana
# Processing Record 38 of Set 7 | malanje
# Processing Record 39 of Set 7 | kapoeta
# Processing Record 40 of Set 7 | imuris
# Processing Record 41 of Set 7 | dubrovka
# Processing Record 42 of Set 7 | quesnel
# Processing Record 43 of Set 7 | sorong
# Processing Record 44 of Set 7 | port macquarie
# Processing Record 45 of Set 7 | lenki
# City not found. Skipping...
# Processing Record 46 of Set 7 | svetlyy
# Processing Record 47 of Set 7 | yar-sale
# Processing Record 48 of Set 7 | port hardy
# Processing Record 49 of Set 7 | pringsewu
# Processing Record 50 of Set 7 | muisne
# Processing Record 1 of Set 8 | anadyr
# Processing Record 2 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 3 of Set 8 | kloulklubed
# Processing Record 4 of Set 8 | saint-ambroise
# Processing Record 5 of Set 8 | dicabisagan
# Processing Record 6 of Set 8 | lebu
# Processing Record 7 of Set 8 | girona
# Processing Record 8 of Set 8 | isangel
# Processing Record 9 of Set 8 | nouadhibou
# Processing Record 10 of Set 8 | houma
# Processing Record 11 of Set 8 | paita
# Processing Record 12 of Set 8 | port hedland
# Processing Record 13 of Set 8 | darhan
# Processing Record 14 of Set 8 | catamarca
# Processing Record 15 of Set 8 | teixoso
# Processing Record 16 of Set 8 | bandarbeyla
# Processing Record 17 of Set 8 | lorengau
# Processing Record 18 of Set 8 | sibu
# Processing Record 19 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 20 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 21 of Set 8 | seymchan
# Processing Record 22 of Set 8 | jilmah
# City not found. Skipping...
# Processing Record 23 of Set 8 | podosinovets
# Processing Record 24 of Set 8 | litoral del san juan
# City not found. Skipping...
# Processing Record 25 of Set 8 | shuyskoye
# Processing Record 26 of Set 8 | bengkulu
# Processing Record 27 of Set 8 | ampanihy
# Processing Record 28 of Set 8 | salym
# Processing Record 29 of Set 8 | bekhtery
# Processing Record 30 of Set 8 | teguldet
# Processing Record 31 of Set 8 | batagay-alyta
# Processing Record 32 of Set 8 | te anau
# Processing Record 33 of Set 8 | leningradskiy
# Processing Record 34 of Set 8 | paragominas
# Processing Record 35 of Set 8 | chapais
# Processing Record 36 of Set 8 | bud
# Processing Record 37 of Set 8 | cao bang
# Processing Record 38 of Set 8 | acapulco
# Processing Record 39 of Set 8 | belaya gora
# Processing Record 40 of Set 8 | astoria
# Processing Record 41 of Set 8 | maneadero
# Processing Record 42 of Set 8 | pevek
# Processing Record 43 of Set 8 | kuminskiy
# Processing Record 44 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 45 of Set 8 | meulaboh
# Processing Record 46 of Set 8 | san juan
# Processing Record 47 of Set 8 | taicheng
# Processing Record 48 of Set 8 | jupiter
# Processing Record 49 of Set 8 | galveston
# Processing Record 50 of Set 8 | leshan
# Processing Record 1 of Set 9 | coquimbo
# Processing Record 2 of Set 9 | atlantic city
# Processing Record 3 of Set 9 | borama
# City not found. Skipping...
# Processing Record 4 of Set 9 | geraldton
# Processing Record 5 of Set 9 | roald
# Processing Record 6 of Set 9 | hofn
# Processing Record 7 of Set 9 | mananjary
# Processing Record 8 of Set 9 | bangassou
# Processing Record 9 of Set 9 | kant
# Processing Record 10 of Set 9 | nisia floresta
# Processing Record 11 of Set 9 | cayenne
# Processing Record 12 of Set 9 | fredericksburg
# Processing Record 13 of Set 9 | anito
# Processing Record 14 of Set 9 | imbituba
# Processing Record 15 of Set 9 | half moon bay
# Processing Record 16 of Set 9 | fevralsk
# City not found. Skipping...
# Processing Record 17 of Set 9 | karratha
# Processing Record 18 of Set 9 | uniao da victoria
# City not found. Skipping...
# Processing Record 19 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 20 of Set 9 | kudahuvadhoo
# Processing Record 21 of Set 9 | ancud
# Processing Record 22 of Set 9 | neuquen
# Processing Record 23 of Set 9 | iskateley
# Processing Record 24 of Set 9 | kaduy
# Processing Record 25 of Set 9 | bilma
# Processing Record 26 of Set 9 | simoes
# Processing Record 27 of Set 9 | katobu
# Processing Record 28 of Set 9 | baherden
# Processing Record 29 of Set 9 | polovinnoye
# Processing Record 30 of Set 9 | shunyi
# Processing Record 31 of Set 9 | haibowan
# City not found. Skipping...
# Processing Record 32 of Set 9 | fort nelson
# Processing Record 33 of Set 9 | burdur
# Processing Record 34 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 35 of Set 9 | lubango
# Processing Record 36 of Set 9 | nizhnyaya tavda
# Processing Record 37 of Set 9 | khartoum
# Processing Record 38 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 39 of Set 9 | pangai
# Processing Record 40 of Set 9 | bambanglipuro
# Processing Record 41 of Set 9 | ketchikan
# Processing Record 42 of Set 9 | yeniseysk
# Processing Record 43 of Set 9 | gravdal
# Processing Record 44 of Set 9 | tarudant
# City not found. Skipping...
# Processing Record 45 of Set 9 | higuey
# City not found. Skipping...
# Processing Record 46 of Set 9 | maraa
# Processing Record 47 of Set 9 | whitecourt
# Processing Record 48 of Set 9 | north vanlaiphai
# Processing Record 49 of Set 9 | tatawin
# Processing Record 50 of Set 9 | mudon
# Processing Record 1 of Set 10 | anloga
# Processing Record 2 of Set 10 | heubach
# Processing Record 3 of Set 10 | tambul
# City not found. Skipping...
# Processing Record 4 of Set 10 | haines junction
# Processing Record 5 of Set 10 | adrar
# Processing Record 6 of Set 10 | wanning
# Processing Record 7 of Set 10 | belmonte
# Processing Record 8 of Set 10 | chernyshevskiy
# Processing Record 9 of Set 10 | ayan
# Processing Record 10 of Set 10 | barcelos
# Processing Record 11 of Set 10 | maniwaki
# Processing Record 12 of Set 10 | buraydah
# Processing Record 13 of Set 10 | terney
# Processing Record 14 of Set 10 | ngunguru
# Processing Record 15 of Set 10 | camacha
# Processing Record 16 of Set 10 | hatillo
# Processing Record 17 of Set 10 | santa vitoria do palmar
# Processing Record 18 of Set 10 | biltine
# Processing Record 19 of Set 10 | surgut
# Processing Record 20 of Set 10 | hohhot
# Processing Record 21 of Set 10 | havoysund
# Processing Record 22 of Set 10 | the pas
# Processing Record 23 of Set 10 | hebi
# Processing Record 24 of Set 10 | sambava
# Processing Record 25 of Set 10 | sri aman
# Processing Record 26 of Set 10 | saint-louis
# Processing Record 27 of Set 10 | ulladulla
# Processing Record 28 of Set 10 | dingle
# Processing Record 29 of Set 10 | talaya
# Processing Record 30 of Set 10 | verkh-chebula
# Processing Record 31 of Set 10 | novikovo
# Processing Record 32 of Set 10 | rawson
# Processing Record 33 of Set 10 | brokopondo
# Processing Record 34 of Set 10 | vernon
# Processing Record 35 of Set 10 | jinxiang
# Processing Record 36 of Set 10 | tynda
# Processing Record 37 of Set 10 | aykhal
# Processing Record 38 of Set 10 | labranzagrande
# Processing Record 39 of Set 10 | jiuquan
# Processing Record 40 of Set 10 | ocos
# Processing Record 41 of Set 10 | miquelon
# Processing Record 42 of Set 10 | santo domingo
# Processing Record 43 of Set 10 | erenhot
# Processing Record 44 of Set 10 | gambela
# Processing Record 45 of Set 10 | juchitlan
# Processing Record 46 of Set 10 | egvekinot
# Processing Record 47 of Set 10 | kodinsk
# Processing Record 48 of Set 10 | gat
# Processing Record 49 of Set 10 | chinhoyi
# Processing Record 50 of Set 10 | mandalgovi
# Processing Record 1 of Set 11 | alice springs
# Processing Record 2 of Set 11 | hunza
# City not found. Skipping...
# Processing Record 3 of Set 11 | raudeberg
# Processing Record 4 of Set 11 | cartagena
# Processing Record 5 of Set 11 | marsh harbour
# Processing Record 6 of Set 11 | pokaran
# Processing Record 7 of Set 11 | iranshahr
# Processing Record 8 of Set 11 | shakawe
# Processing Record 9 of Set 11 | sumbe
# Processing Record 10 of Set 11 | rhyl
# Processing Record 11 of Set 11 | santa cruz cabralia
# Processing Record 12 of Set 11 | asau
# Processing Record 13 of Set 11 | moroni
# Processing Record 14 of Set 11 | lupiro
# Processing Record 15 of Set 11 | garowe
# Processing Record 16 of Set 11 | kynsperk nad ohri
# Processing Record 17 of Set 11 | carnarvon
# Processing Record 18 of Set 11 | charyshskoye
# Processing Record 19 of Set 11 | kuito
# Processing Record 20 of Set 11 | lasa
# Processing Record 21 of Set 11 | isiro
# Processing Record 22 of Set 11 | norsup
# Processing Record 23 of Set 11 | nueve de julio
# Processing Record 24 of Set 11 | sioux lookout
# Processing Record 25 of Set 11 | kavaratti
# Processing Record 26 of Set 11 | cap malheureux
# Processing Record 27 of Set 11 | saint-leu
# Processing Record 28 of Set 11 | sabang
# Processing Record 29 of Set 11 | sao miguel do oeste
# City not found. Skipping...
# Processing Record 30 of Set 11 | bouca
# Processing Record 31 of Set 11 | mailsi
# Processing Record 32 of Set 11 | dilla
# Processing Record 33 of Set 11 | plettenberg bay
# Processing Record 34 of Set 11 | san pablo
# Processing Record 35 of Set 11 | grafing
# Processing Record 36 of Set 11 | sinnamary
# Processing Record 37 of Set 11 | outlook
# Processing Record 38 of Set 11 | munxar
# Processing Record 39 of Set 11 | harij
# Processing Record 40 of Set 11 | nantucket
# Processing Record 41 of Set 11 | krasnyy yar
# Processing Record 42 of Set 11 | kitami
# Processing Record 43 of Set 11 | tevriz
# Processing Record 44 of Set 11 | mitsamiouli
# Processing Record 45 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 46 of Set 11 | lewisporte
# Processing Record 47 of Set 11 | daru
# Processing Record 48 of Set 11 | andra
# Processing Record 49 of Set 11 | rundu
# Processing Record 50 of Set 11 | lhuntshi
# City not found. Skipping...
# Processing Record 1 of Set 12 | pirmasens
# Processing Record 2 of Set 12 | virginia beach
# Processing Record 3 of Set 12 | baiao
# Processing Record 4 of Set 12 | geneva
# Processing Record 5 of Set 12 | sangar
# Processing Record 6 of Set 12 | port keats
# Processing Record 7 of Set 12 | dubbo
# Processing Record 8 of Set 12 | qasigiannguit
# Processing Record 9 of Set 12 | chuzhou
# Processing Record 10 of Set 12 | fairbanks
# Processing Record 11 of Set 12 | anderson
# Processing Record 12 of Set 12 | strezhevoy
# Processing Record 13 of Set 12 | ukiah
# Processing Record 14 of Set 12 | zhangjiakou
# Processing Record 15 of Set 12 | bilibino
# Processing Record 16 of Set 12 | portland
# Processing Record 17 of Set 12 | ust-ilimsk
# Processing Record 18 of Set 12 | baijiantan
# Processing Record 19 of Set 12 | kon tum
# Processing Record 20 of Set 12 | kencong
# Processing Record 21 of Set 12 | bukachacha
# Processing Record 22 of Set 12 | moissala
# Processing Record 23 of Set 12 | jiaonan
# Processing Record 24 of Set 12 | luanda
# Processing Record 25 of Set 12 | pasaquina
# Processing Record 26 of Set 12 | cervo
# Processing Record 27 of Set 12 | fairlie
# Processing Record 28 of Set 12 | baykit
# Processing Record 29 of Set 12 | tiruchchendur
# Processing Record 30 of Set 12 | busayra
# Processing Record 31 of Set 12 | dong hoi
# Processing Record 32 of Set 12 | mackenzie
# Processing Record 33 of Set 12 | wajima
# Processing Record 34 of Set 12 | swan hill
# Processing Record 35 of Set 12 | tiznit
# Processing Record 36 of Set 12 | makushino
# Processing Record 37 of Set 12 | ilhabela
# Processing Record 38 of Set 12 | danville
# Processing Record 39 of Set 12 | palmer
# Processing Record 40 of Set 12 | brae
# Processing Record 41 of Set 12 | alta floresta
# Processing Record 42 of Set 12 | rio chiquito
# Processing Record 43 of Set 12 | comodoro rivadavia
# Processing Record 44 of Set 12 | novoagansk
# Processing Record 45 of Set 12 | ouegoa
# Processing Record 46 of Set 12 | olinda
# Processing Record 47 of Set 12 | pincher creek
# Processing Record 48 of Set 12 | siniscola
# Processing Record 49 of Set 12 | sant julia de loria
# Processing Record 50 of Set 12 | dandong
# Processing Record 1 of Set 13 | mandan
# Processing Record 2 of Set 13 | san cristobal
# Processing Record 3 of Set 13 | rudbar
# Processing Record 4 of Set 13 | semey
# Processing Record 5 of Set 13 | biskamzha
# Processing Record 6 of Set 13 | batsfjord
# Processing Record 7 of Set 13 | presidente epitacio
# Processing Record 8 of Set 13 | abu dhabi
# Processing Record 9 of Set 13 | khorixas
# Processing Record 10 of Set 13 | hong gai
# Processing Record 11 of Set 13 | tazovskiy
# Processing Record 12 of Set 13 | poum
# Processing Record 13 of Set 13 | warah
# Processing Record 14 of Set 13 | hortolandia
# Processing Record 15 of Set 13 | ola
# Processing Record 16 of Set 13 | olafsvik
# Processing Record 17 of Set 13 | payakumbuh
# Processing Record 18 of Set 13 | ducheng
# Processing Record 19 of Set 13 | vestmanna
# Processing Record 20 of Set 13 | guatire
# Processing Record 21 of Set 13 | napanee
# Processing Record 22 of Set 13 | yatou
# Processing Record 23 of Set 13 | balkhash
# Processing Record 24 of Set 13 | kitimat
# Processing Record 25 of Set 13 | victor harbor
# Processing Record 26 of Set 13 | jiangyou
# Processing Record 27 of Set 13 | westport
# Processing Record 28 of Set 13 | valcau de jos
# Processing Record 29 of Set 13 | ambilobe
# Processing Record 30 of Set 13 | ahipara
# Processing Record 31 of Set 13 | matara
# Processing Record 32 of Set 13 | rio gallegos
# Processing Record 33 of Set 13 | tucson
# Processing Record 34 of Set 13 | inhambupe
# Processing Record 35 of Set 13 | arlit
# Processing Record 36 of Set 13 | harbour breton
# Processing Record 37 of Set 13 | jacmel
# Processing Record 38 of Set 13 | gumdag
# Processing Record 39 of Set 13 | kirakira
# Processing Record 40 of Set 13 | castelnaudary
# Processing Record 41 of Set 13 | nacala
# Processing Record 42 of Set 13 | normandin
# Processing Record 43 of Set 13 | sarangani
# Processing Record 44 of Set 13 | lima
# Processing Record 45 of Set 13 | kirillov
# Processing Record 46 of Set 13 | vaitupu
# City not found. Skipping...
# Processing Record 47 of Set 13 | ulychne
# Processing Record 48 of Set 13 | lengshuitan
# Processing Record 49 of Set 13 | langsa
# Processing Record 50 of Set 13 | san felipe
# Processing Record 1 of Set 14 | sokoni
# Processing Record 2 of Set 14 | rapid valley
# Processing Record 3 of Set 14 | sao joao da barra
# Processing Record 4 of Set 14 | ojinaga
# Processing Record 5 of Set 14 | bandrele
# Processing Record 6 of Set 14 | gamba
# Processing Record 7 of Set 14 | benguela
# Processing Record 8 of Set 14 | marystown
# Processing Record 9 of Set 14 | rosario
# Processing Record 10 of Set 14 | aitape
# Processing Record 11 of Set 14 | mala
# Processing Record 12 of Set 14 | vondrozo
# Processing Record 13 of Set 14 | mocuba
# Processing Record 14 of Set 14 | jhanjharpur
# Processing Record 15 of Set 14 | sao sebastiao
# Processing Record 16 of Set 14 | bargal
# City not found. Skipping...
# Processing Record 17 of Set 14 | antakya
# Processing Record 18 of Set 14 | charters towers
# Processing Record 19 of Set 14 | macas
# Processing Record 20 of Set 14 | rodental
# Processing Record 21 of Set 14 | cacequi
# Processing Record 22 of Set 14 | camana
# Processing Record 23 of Set 14 | port augusta
# Processing Record 24 of Set 14 | flinders
# Processing Record 25 of Set 14 | saint anthony
# Processing Record 26 of Set 14 | arica
# Processing Record 27 of Set 14 | ferme-neuve
# Processing Record 28 of Set 14 | darnah
# Processing Record 29 of Set 14 | deputatskiy
# Processing Record 30 of Set 14 | tilichiki
# Processing Record 31 of Set 14 | mnogovershinnyy
# Processing Record 32 of Set 14 | okhotsk
# Processing Record 33 of Set 14 | nicoya
# Processing Record 34 of Set 14 | marfino
# Processing Record 35 of Set 14 | sidrolandia
# Processing Record 36 of Set 14 | tura
# Processing Record 37 of Set 14 | san policarpo
# Processing Record 38 of Set 14 | himi
# Processing Record 39 of Set 14 | tooele
# Processing Record 40 of Set 14 | monteiro
# Processing Record 41 of Set 14 | faya
# Processing Record 42 of Set 14 | carutapera
# Processing Record 43 of Set 14 | damghan
# Processing Record 44 of Set 14 | atar
# Processing Record 45 of Set 14 | soe
# Processing Record 46 of Set 14 | komsomolskiy
# Processing Record 47 of Set 14 | srednekolymsk
# Processing Record 48 of Set 14 | linxia
# Processing Record 49 of Set 14 | terny
# Processing Record 50 of Set 14 | santa rosa
# Processing Record 1 of Set 15 | latung
# Processing Record 2 of Set 15 | sibolga
# Processing Record 3 of Set 15 | chuguyevka
# Processing Record 4 of Set 15 | tuggurt
# City not found. Skipping...
# Processing Record 5 of Set 15 | rabo de peixe
# Processing Record 6 of Set 15 | huayang
# Processing Record 7 of Set 15 | akyab
# Processing Record 8 of Set 15 | nago
# Processing Record 9 of Set 15 | phan rang
# City not found. Skipping...
# Processing Record 10 of Set 15 | harper
# Processing Record 11 of Set 15 | iberia
# Processing Record 12 of Set 15 | gushikawa
# Processing Record 13 of Set 15 | mayor pablo lagerenza
# Processing Record 14 of Set 15 | balkanabat
# Processing Record 15 of Set 15 | beloha
# Processing Record 16 of Set 15 | inyonga
# Processing Record 17 of Set 15 | garmsar
# Processing Record 18 of Set 15 | senanga
# Processing Record 19 of Set 15 | zabol
# Processing Record 20 of Set 15 | bakchar
# Processing Record 21 of Set 15 | clearwater
# Processing Record 22 of Set 15 | van
# Processing Record 23 of Set 15 | tawkar
# City not found. Skipping...
# Processing Record 24 of Set 15 | channel-port aux basques
# Processing Record 25 of Set 15 | kvitok
# Processing Record 26 of Set 15 | mokhsogollokh
# Processing Record 27 of Set 15 | angra
# City not found. Skipping...
# Processing Record 28 of Set 15 | turayf
# Processing Record 29 of Set 15 | portsmouth
# Processing Record 30 of Set 15 | ljubimec
# City not found. Skipping...
# Processing Record 31 of Set 15 | atasu
# Processing Record 32 of Set 15 | castlebar
# Processing Record 33 of Set 15 | rassvet
# Processing Record 34 of Set 15 | tortoli
# Processing Record 35 of Set 15 | moron
# Processing Record 36 of Set 15 | meyungs
# City not found. Skipping...
# Processing Record 37 of Set 15 | sur
# Processing Record 38 of Set 15 | port moresby
# Processing Record 39 of Set 15 | gandai
# Processing Record 40 of Set 15 | inhambane
# Processing Record 41 of Set 15 | amapa
# Processing Record 42 of Set 15 | palakkad
# Processing Record 43 of Set 15 | mount isa
# Processing Record 44 of Set 15 | tadine
# Processing Record 45 of Set 15 | eureka
# Processing Record 46 of Set 15 | zbarazh
# Processing Record 47 of Set 15 | agustin codazzi
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0           Vardo      NO  70.37   31.11     45.14        85         100
# 1  Ribeira Grande      PT  38.52  -28.70     63.64        74          96
# 2  Port Elizabeth      ZA -33.92   25.57     64.40        88          40
# 3          Maceio      BR  -9.67  -35.74     75.20        88           0
# 4        Ylojarvi      FI  61.56   23.60     46.40        81          90
# 5            Hami      CN  42.80   93.45     39.79        59           0
# 6       Novorzhev      RU  57.03   29.33     34.39        91           5
# 7  Saint-Philippe      RE -21.36   55.77     69.80        56          90
# 8       Alyangula      AU -13.85  136.42     96.80        26          70
# 9           Kutum      SD  14.20   24.67     70.81        33           0
#
#    Wind Speed Current Description
# 0       28.32     overcast clouds
# 1       18.66     overcast clouds
# 2       11.41    scattered clouds
# 3        6.93           clear sky
# 4       13.87     overcast clouds
# 5        7.07           clear sky
# 6        4.14           clear sky
# 7        5.82     overcast clouds
# 8        8.05       broken clouds
# 9       17.16           clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
